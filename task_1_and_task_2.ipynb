# %%
# import pandas as pd
# df = pd.read_csv('data/MachineLearningRating_v3.txt', delimiter='|', low_memory=False)
# df.to_csv('data/MachineLearningRating_v3.csv', index=False)

# %%
# data = pd.read_csv('data/MachineLearningRating_v3.csv')
# data.head()
# Out:
# C:\Users\gutemaf\AppData\Local\Temp\2\ipykernel_16348\2292889382.py:1: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('data/MachineLearningRating_v3.csv')
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# ...

# %%
# data.columns
# Out:
# Index(['UnderwrittenCoverID', 'PolicyID', 'TransactionMonth',
#        'IsVATRegistered', 'Citizenship', 'LegalType', 'Title', 'Language',
#        'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province',
#        'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode',
#        'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders',
#        'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors',
#        'VehicleIntroDate', 'CustomValueEstimate', 'AlarmImmobiliser',
#        'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff',
#        'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet',
#        'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm',
#        'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section',
#        'Product', 'StatutoryClass', 'StatutoryRiskType', 'TotalPremium',
#        'TotalClaims'],
#       dtype='object')

# %%
# import pprint
# pprint.pprint(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  int64
#  1   PolicyID                  1000098 non-null  int64
#  2   TransactionMonth          1000098 non-null  object
#  3   IsVATRegistered           1000098 non-null  bool
#  4   Citizenship               1000098 non-null  object
#  5   LegalType                 1000098 non-null  object
#  6   Title                     1000098 non-null  object
#  7   Language                  1000098 non-null  object
#  8   Bank                      854137 non-null   object
#  9   AccountType               959866 non-null   object
#  10  MaritalStatus             991839 non-null   object
#  11  Gender                    990562 non-null   object
#  12  Country                   1000098 non-null  object
# ...

# %%
# data.shape
# Out:
# (1000098, 52)

# %%
# # amount of client VATRegistered
# data['IsVATRegistered'].value_counts()
# Out:
# IsVATRegistered
# False    995075
# True       5023
# Name: count, dtype: int64

# %%
# data['Citizenship'].value_counts()
# Out:
# Citizenship
#       895210
# ZA    103721
# ZW       936
# AF       231
# Name: count, dtype: int64

# %%
# null_citizen = data['Citizenship'].isnull().sum()
# print(null_citizen)
# Out:
# 0

# %%
# data_nan = pd.read_csv('data/MachineLearningRating_v3_with_nan.csv')

# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns


# df['TransactionMonth'] = pd.to_datetime(df['TransactionMonth'], errors='coerce')

# # Check the conversion
# # print(df['TransactionMonth'].head())

# # Drop rows where 'TransactionMonth' or 'TotalPremium' is NaN
# df = df.dropna(subset=['TransactionMonth', 'TotalPremium'])

# # Group by month and aggregate total premium
# monthly_premium = df.groupby(df['TransactionMonth'].dt.to_period('M')).agg({'TotalPremium': 'sum'}).reset_index()
# monthly_premium['TransactionMonth'] = monthly_premium['TransactionMonth'].dt.to_timestamp()

# # Plot
# plt.figure(figsize=(12, 6))

# # Line plot to show trend over time
# sns.lineplot(data=monthly_premium, x='TransactionMonth', y='TotalPremium')

# plt.title('Total Premium Over Time')
# plt.xlabel('Transaction Month')
# plt.ylabel('Total Premium')
# plt.xticks(rotation=45)
# plt.grid(True)
# plt.tight_layout()

# # Show the plot
# plt.show()
# Out:
# C:\Users\gutemaf\AppData\Local\Temp\2\ipykernel_16348\2341937051.py:1: DtypeWarning: Columns (4,32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_nan = pd.read_csv('data/MachineLearningRating_v3_with_nan.csv')

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns

# # Plot histograms for numerical features
# numerical_columns = ['TotalPremium', 'TotalClaims']  # Add more if needed

# plt.figure(figsize=(14, 6))
# for i, col in enumerate(numerical_columns, 1):
#     plt.subplot(1, len(numerical_columns), i)
#     sns.histplot(data_nan[col], bins=30, kde=True)
#     plt.title(f'Distribution of {col}')
# plt.tight_layout()
# plt.show()

# %%
# # Plot bar charts for categorical features
# categorical_columns = ['Citizenship', 'Bank']  # Add more if needed

# plt.figure(figsize=(14, 6))
# for i, col in enumerate(categorical_columns, 1):
#     plt.subplot(1, len(categorical_columns), i)
#     sns.countplot(y=data_nan[col], order=data_nan[col].value_counts().index)
#     plt.title(f'Distribution of {col}')
# plt.tight_layout()
# plt.show()

# %%
# # Scatter plot of TotalPremium vs. TotalClaims
# plt.figure(figsize=(12, 6))
# sns.scatterplot(x='TotalPremium', y='TotalClaims', hue='PostalCode', data=data_nan)
# plt.title('Total Premium vs. Total Claims by Postal Code')
# plt.xlabel('Total Premium')
# plt.ylabel('Total Claims')
# plt.grid(True)
# plt.show()

# # Correlation matrix heatmap
# correlation_matrix = data_nan[['TotalPremium', 'TotalClaims', 'CustomValueEstimate', 'NumberOfVehiclesInFleet']].corr()
# plt.figure(figsize=(8, 6))
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
# plt.title('Correlation Matrix')
# plt.show()

# %%
# # Trend over geography (example using PostalCode)
# plt.figure(figsize=(14, 6))
# sns.lineplot(data=df.groupby('PostalCode')['TotalPremium'].mean().reset_index(), x='PostalCode', y='TotalPremium')
# plt.title('Average Total Premium by Postal Code')
# plt.xlabel('Postal Code')
# plt.ylabel('Average Total Premium')
# plt.xticks(rotation=90)
# plt.grid(True)
# plt.show()

# %%
# plt.figure(figsize=(14, 6))

# # Calculate average TotalPremium and TotalClaims by PostalCode
# grouped_data = df.groupby('PostalCode').agg({'TotalPremium': 'mean', 'TotalClaims': 'mean'}).reset_index()

# # Plot TotalPremium
# sns.lineplot(data=grouped_data, x='PostalCode', y='TotalPremium', label='Average Total Premium', color='blue')

# # Plot TotalClaims on the same graph
# sns.lineplot(data=grouped_data, x='PostalCode', y='TotalClaims', label='Average Total Claims', color='orange')

# # Add title and labels
# plt.title('Average Total Premium and Total Claims by Postal Code')
# plt.xlabel('Postal Code')
# plt.ylabel('Average Values')
# plt.xticks(rotation=90)
# plt.grid(True)

# # Show legend
# plt.legend()

# plt.tight_layout()
# plt.show()

# %%
# # Plot box plots for numerical features
# plt.figure(figsize=(14, 6))
# for i, col in enumerate(numerical_columns, 1):
#     plt.subplot(1, len(numerical_columns), i)
#     sns.boxplot(x=data_nan[col])
#     plt.title(f'Box Plot of {col}')
# plt.tight_layout()
# plt.show()

# %%
# plt.figure(figsize=(12, 6))
# sns.lineplot(data=monthly_premium, x='TransactionMonth', y='TotalPremium')
# plt.title('Total Premium Over Time with Annotations')
# plt.xlabel('Transaction Month')
# plt.ylabel('Total Premium')
# plt.xticks(rotation=45)
# plt.grid(True)
# plt.tight_layout()
# plt.show()

# %%
# g = sns.FacetGrid(df, col='Citizenship', hue='Bank', col_wrap=4, height=5)
# g.map(sns.histplot, 'TotalPremium')
# g.add_legend()
# plt.show()

# %%
# sns.pairplot(df[['TotalPremium', 'TotalClaims']], kind='kde')
# plt.show()
